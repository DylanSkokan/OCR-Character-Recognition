# %%
import os
import platform
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from urllib.request import urlretrieve
from sklearn.preprocessing import LabelEncoder

# paths and directories
project_root = os.path.abspath("")
data_directory = os.path.join(project_root, "batch_1")
images_directory = os.path.join(data_directory, "background_images")
json_file_path = os.path.join(data_directory, "JSON", "kaggle_data_1.json")

image_file_extenstions = ["jpg"]

df = pd.read_json(json_file_path)

# # set directory to project root
# os.chdir(project_root)

def clear_console ():
    if platform.system() == "Windows":
        os.system("cls")
    else:
        os.system("clear")      
# end clear_console
clear_console()

display(df.head(2))
# Out:
#                                                latex  \
# 0  \lim_{a\to\frac{\pi}{4}}\frac{\frac{d}{da}\lef...
# 1  \lim_{w\to\pi/5^{-}}\frac{\tan^{2}{w}}{2\frac{...
#
#                                    uuid  \
# 0  bd85ee85-2549-4539-9cd9-122d0ea3dca2
# 1  e97b0b1f-08bf-4c2b-86cb-f264af2160df
#
#                                          unicode_str  \
# 0  ƀ{aƄಭ{ೃ}{4}}ಭ{ಭ{d}{da}ಷƇ{a}+-6Ɔ{a}ೌ}{ಭ{d}{da}ಷ...
# 1      ƀ{wƄೃ/5^{-}}ಭ{Ɖ^{2}{w}}{2ಭ{-4}{3w+ಷ-3ೃೌ^{4}}}
#
#                 unicode_less_curlies  \
# 0  ƀaƄಭೃ4ಭಭddaಷƇa+-6Ɔaೌಭddaಷa+-4ಭೃ4ೌ
# 1        ƀwƄೃ/5^-ಭƉ^2w2ಭ-43w+ಷ-3ೃೌ^4
#
#                                           image_data     font  \
# 0  {'full_latex_chars': ['\lim_', '{', 'a', '\to'...  Oct_011
# 1  {'full_latex_chars': ['\lim_', '{', 'w', '\to'...     C017
#
#                                    filename
# 0  bd85ee85-2549-4539-9cd9-122d0ea3dca2.jpg
# 1  e97b0b1f-08bf-4c2b-86cb-f264af2160df.jpg

# %%
def get_dataframe_properties (frame):
    frame_length = len(frame)
    #print("type:", type(frame))
    null_value_count = frame.isnull().sum().sum()
    #dupes = frame.duplicated()
    #duplicate_row_count = print(type(frame.duplicated()))

    percent_null = null_value_count / frame_length * 100
    percent_duplicates = 0 #duplicate_row_count / frame_length * 100
    #print(frame.describe())
    #print(frame.head())
    
    print ("Column Information")
    print("Index Name\t\t\tData Type\t\tDimension")
    index = 0
    for column in frame.columns:
        print(index, " ", column, "\t\t\t\t", frame[column].dtype, "\t", frame[column].shape)
        index += 1
        
    print("percent nulls:", percent_null)
    print("percent duplicates:", percent_duplicates)
    print("total elements:", frame.size)
    print("row count", len(frame))
    print("width:", len(frame.columns))
    
    """
    print("\nSummary Statistics")
    print("-------------------")
    print(frame.describe())
    """
    print("First Five Rows")
    print("-------------------")
    print(frame.head())
    
    #print("Value Counts")
    #print("------------")
    #print(frame.value_counts())
# end get_dataframe_properties

get_dataframe_properties(df)
# Out:
# Column Information
# Index Name			Data Type		Dimension
# 0   latex 				 object 	 (10000,)
# 1   uuid 				 object 	 (10000,)
# 2   unicode_str 				 object 	 (10000,)
# 3   unicode_less_curlies 				 object 	 (10000,)
# 4   image_data 				 object 	 (10000,)
# 5   font 				 object 	 (10000,)
# 6   filename 				 object 	 (10000,)
# percent nulls: 0.0
# percent duplicates: 0
# total elements: 70000
# row count 10000
# width: 7
# First Five Rows
# -------------------
#                                                latex  \
# 0  \lim_{a\to\frac{\pi}{4}}\frac{\frac{d}{da}\lef...
# 1  \lim_{w\to\pi/5^{-}}\frac{\tan^{2}{w}}{2\frac{...
# 2  e^{\lim_{b\to4^{+}}\frac{\frac{7}{b+3}}{\cos{b}}}
# 3  \lim_{\theta\to\pi/8}\tan^{3}{\theta}+\lim_{\t...
# 4  =\lim_{x\to8^{+}}\frac{-9\tan{x}\sec^{1}{x}}{\...
#
#                                    uuid  \
# 0  bd85ee85-2549-4539-9cd9-122d0ea3dca2
# 1  e97b0b1f-08bf-4c2b-86cb-f264af2160df
# 2  3c72e1a1-c1de-4d67-a0ad-9f7afb6cee01
# 3  54459370-7cbe-423a-88bb-697d3864d12a
# 4  da71ce9d-e1a1-4bb2-abce-77a29c45024f
#
#                                          unicode_str  \
# 0  ƀ{aƄಭ{ೃ}{4}}ಭ{ಭ{d}{da}ಷƇ{a}+-6Ɔ{a}ೌ}{ಭ{d}{da}ಷ...
# 1      ƀ{wƄೃ/5^{-}}ಭ{Ɖ^{2}{w}}{2ಭ{-4}{3w+ಷ-3ೃೌ^{4}}}
# 2                   e^{ƀ{bƄ4^{+}}ಭ{ಭ{7}{b+3}}{ƅ{b}}}
# 3                  ƀ{೨Ƅೃ/8}Ɖ^{3}{೨}+ƀ{೨Ƅೃ/6}ƅ^{7}{೨}
# 4  =ƀ{xƄ8^{+}}ಭ{-9Ɖ{x}Ɔ^{1}{x}}{Ƈ^{1}{x}+ಷxƉ{x}+3...
#
#                 unicode_less_curlies  \
# 0  ƀaƄಭೃ4ಭಭddaಷƇa+-6Ɔaೌಭddaಷa+-4ಭೃ4ೌ
# 1        ƀwƄೃ/5^-ಭƉ^2w2ಭ-43w+ಷ-3ೃೌ^4
# 2                   e^ƀbƄ4^+ಭಭ7b+3ƅb
# 3              ƀ೨Ƅೃ/8Ɖ^3೨+ƀ೨Ƅೃ/6ƅ^7೨
# 4   =ƀxƄ8^+ಭ-9ƉxƆ^1xƇ^1x+ಷxƉx+3ೌƇ^5x
#
#                                           image_data     font  \
# 0  {'full_latex_chars': ['\lim_', '{', 'a', '\to'...  Oct_011
# 1  {'full_latex_chars': ['\lim_', '{', 'w', '\to'...     C017
# 2  {'full_latex_chars': ['e', '^', '{', '\lim_', ...  Oct_095
# 3  {'full_latex_chars': ['\lim_', '{', '\theta', ...  Oct_203
# 4  {'full_latex_chars': ['=', '\lim_', '{', 'x', ...     C004
#
#                                    filename
# 0  bd85ee85-2549-4539-9cd9-122d0ea3dca2.jpg
# 1  e97b0b1f-08bf-4c2b-86cb-f264af2160df.jpg
# 2  3c72e1a1-c1de-4d67-a0ad-9f7afb6cee01.jpg
# 3  54459370-7cbe-423a-88bb-697d3864d12a.jpg
# 4  da71ce9d-e1a1-4bb2-abce-77a29c45024f.jpg

# %%
def drop_extraneous_columns (frame, columns):
    for column in columns:
        print("Dropping", column)
        frame.drop(column, axis="columns", inplace=True)
# end drop_extraneous_columns

def convert_column_to_string ():
    #df[["latex", "uuid", "unicode_str"]] =  df[["latex", "uuid", "unicode_str"]].astype("string") 
    #df[["unicode_str", "unicode_less_curlies"]] =  df[["unicode_str", "unicode_less_curlies"]].astype("unicode") 
    df[["latex", "font", "filename"]] =  df[["latex", "font", "filename"]].astype("string")    
    for column in df.columns:
        print(column, "", df[column].dtype)
        print(df[column])
# end convert_column-to_string   

drop_extraneous_columns(df, ["uuid", "unicode_str", "unicode_less_curlies"])
convert_column_to_string()
# Out:
# Dropping uuid
# Dropping unicode_str
# Dropping unicode_less_curlies
# latex  string
# 0       \lim_{a\to\frac{\pi}{4}}\frac{\frac{d}{da}\lef...
# 1       \lim_{w\to\pi/5^{-}}\frac{\tan^{2}{w}}{2\frac{...
# 2       e^{\lim_{b\to4^{+}}\frac{\frac{7}{b+3}}{\cos{b}}}
# 3       \lim_{\theta\to\pi/8}\tan^{3}{\theta}+\lim_{\t...
# 4       =\lim_{x\to8^{+}}\frac{-9\tan{x}\sec^{1}{x}}{\...
#                               ...
# 9995    \lim_{h\to\frac{\pi}{3}}\frac{8\cos{h}+-2\csc{...
# 9996    \lim_{g\to3^{+}}-4\frac{3\cos{g}\cos{g}}{\tan{...
# 9997    =\lim_{p\to\pi/5^{-}}5/3\tan^{8}{p}\left(2p+\l...
# 9998    \lim_{x\to\frac{\pi}{3}}\frac{5\sin{x}+-2\tan{...
# 9999    \lim_{h\to\frac{\pi}{8}^{-}}\frac{9}{3}\cos^{7...
# Name: latex, Length: 10000, dtype: string
# image_data  object
# 0       {'full_latex_chars': ['\lim_', '{', 'a', '\to'...
# 1       {'full_latex_chars': ['\lim_', '{', 'w', '\to'...
# 2       {'full_latex_chars': ['e', '^', '{', '\lim_', ...
# 3       {'full_latex_chars': ['\lim_', '{', '\theta', ...
# 4       {'full_latex_chars': ['=', '\lim_', '{', 'x', ...
#                               ...
# 9995    {'full_latex_chars': ['\lim_', '{', 'h', '\to'...
# 9996    {'full_latex_chars': ['\lim_', '{', 'g', '\to'...
# 9997    {'full_latex_chars': ['=', '\lim_', '{', 'p', ...
# 9998    {'full_latex_chars': ['\lim_', '{', 'x', '\to'...
# 9999    {'full_latex_chars': ['\lim_', '{', 'h', '\to'...
# Name: image_data, Length: 10000, dtype: object
# font  string
# 0       Oct_011
# 1          C017
# 2       Oct_095
# 3       Oct_203
# 4          C004
#          ...
# 9995    Oct_166
# 9996       C038
# 9997    Oct_056
# 9998       C014
# 9999       C063
# Name: font, Length: 10000, dtype: string
# filename  string
# 0       bd85ee85-2549-4539-9cd9-122d0ea3dca2.jpg
# 1       e97b0b1f-08bf-4c2b-86cb-f264af2160df.jpg
# 2       3c72e1a1-c1de-4d67-a0ad-9f7afb6cee01.jpg
# 3       54459370-7cbe-423a-88bb-697d3864d12a.jpg
# 4       da71ce9d-e1a1-4bb2-abce-77a29c45024f.jpg
#                           ...
# 9995    c55a3526-4213-4a2c-b7d5-4ca4ba0e4be2.jpg
# 9996    4b84077b-79bf-47f5-9315-0e1801bd64f1.jpg
# 9997    2e01dbe2-6843-4b9c-8c53-4237b6c52f67.jpg
# 9998    939a8578-1670-4d76-b4b5-5a743abc9a9d.jpg
# 9999    7a12fd69-31a6-4691-b497-7cb182901f67.jpg
# Name: filename, Length: 10000, dtype: string

# %%
def print_column_descriptions ():
    print("Column Descriptions")
    print("-------------------")
    string = "latex: String--the ground truth latex"
    string += "\n" + "uuid: String"
    string += "\n" + "unicode_str: String--latex as unicode per latex_unicode_map.json"
    string += "\n" + "unicode_less_curlies: String--latex as unicode with curlies removed"
    string += "\n" + "font: String--identifier for the generating font"
    string += "\n" + "filename: String--filename of corresponding image"

    
    image_object_fields = "image_data: {"
    image_object_fields += "\n\t" + "full_latex_chars: List of Strings--each LaTeX token"
    """
        string += "\n" + "visible_latex_chars: List of Strings--only visible LaTeX tokens"
        "visible_char_map": List of Ints--LaTeX tokens per visible_char_map.json, 
        "width": Int--number of pixels of width of image, 
        "height": Int--number of pixels of height of image, 
        "depth": Int--channels of image RGBA, 
        "xmins": List of Floats--normalized position of xmin of bounding box per character, 
        "xmaxs": List of Floats, 
        "ymins": List of Floats, 
        "ymaxs": List of Floats, 
        "xmins_raw": List of Ints--pixel position of xmin of bounding box per character, 
        "xmaxs_raw": List of Ints,
        "ymins_raw": List of Ints,
        "ymaxs_raw": List of Ints,
        "png_masks": List of Strings--the encoded mask per character
        },
    """
    string += "\n" + image_object_fields
    print(string)
# end print_column_description

def label_features ():
    font_label_encoder = LabelEncoder()
    df["font_label"] = font_label_encoder.fit_transform(df["font"])
    print(df["font_label"].values)
#end label_features

print_column_descriptions()
label_features()
# Out:
# Column Descriptions
# -------------------
# latex: String--the ground truth latex
# uuid: String
# unicode_str: String--latex as unicode per latex_unicode_map.json
# unicode_less_curlies: String--latex as unicode with curlies removed
# font: String--identifier for the generating font
# filename: String--filename of corresponding image
# image_data: {
# 	full_latex_chars: List of Strings--each LaTeX token
# [ 80  12 118 ... 103  10  53]

# %%
# check what uuid column contains to verify it can be dropped

# 210 unique fonts.  The y might be clustered or they might need a k-clustering
print(df["font"].unique().shape)
print(df["latex"].unique().shape)

#print(df["unicode_str"], " ", df["unicode_less_curlies"])

# The most direct target is the latex expression.  We should be able to drop all other columns except latex and compare it to the picture metadata.
# The file name will help us test our model
print(df["font_label"])

"""
fig, ax = plt.subplots()
df["font_label"].value_counts().plot(ax=ax, kind="bar")
plt.show()
"""
# Extract the label column
font_labels = df.pop("font_label").values

# Normalize the feature columns using standardization
df = (df - df.mean()) / df.std()

# Determine the number of clusters
k = 20

# Apply k-means clustering
kmeans = KMeans(n_clusters=k, random_state=42)
clusters = kmeans.fit_predict(df.dropna())

# Evaluate the clusters using silhouette score
from sklearn.metrics import silhouette_score
score = silhouette_score(df, clusters)

print(f"Silhouette score: {score}")
# Out:
# (210,)
# (9997,)
# 0        80
# 1        12
# 2       118
# 3       172
# 4         2
#        ...
# 9995    164
# 9996     31
# 9997    103
# 9998     10
# 9999     53
# Name: font_label, Length: 10000, dtype: int32
# C:\Users\Dylan\AppData\Local\Temp\ipykernel_15192\403924001.py:22: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df = (df - df.mean()) / df.std()
# C:\Users\Dylan\AppData\Local\Temp\ipykernel_15192\403924001.py:22: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df = (df - df.mean()) / df.std()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 29
#      27 # Apply k-means clustering
#      28 kmeans = KMeans(n_clusters=k, random_state=42)
# ---> 29 clusters = kmeans.fit_predict(df)
#      31 # Evaluate the clusters using silhouette score
#      32 from sklearn.metrics import silhouette_score
#
# File c:\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:1033, in _BaseKMeans.fit_predict(self, X, y, sample_weight)
#    1010 def fit_predict(self, X, y=None, sample_weight=None):
#    1011     """Compute cluster centers and predict cluster index for each sample.
#    1012
#    1013     Convenience method; equivalent to calling fit(X) followed by
#    (...)
#    1031         Index of the cluster each sample belongs to.
#    1032     """
# -> 1033     return self.fit(X, sample_weight=sample_weight).labels_
#
# File c:\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:1417, in KMeans.fit(self, X, y, sample_weight)
#    1390 """Compute k-means clustering.
#    1391
#    1392 Parameters
#    (...)
#    1413     Fitted estimator.
#    1414 """
#    1415 self._validate_params()
# -> 1417 X = self._validate_data(
#    1418     X,
#    1419     accept_sparse="csr",
#    1420     dtype=[np.float64, np.float32],
#    1421     order="C",
#    1422     copy=self.copy_x,
#    1423     accept_large_sparse=False,
#    1424 )
#    1426 self._check_params_vs_input(X)
#    1428 random_state = check_random_state(self.random_state)
#
# File c:\Python310\lib\site-packages\sklearn\base.py:546, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     544     raise ValueError("Validation should be done on X, y or both.")
#     545 elif not no_val_X and no_val_y:
# --> 546     X = check_array(X, input_name="X", **check_params)
#     547     out = X
#     548 elif no_val_X and not no_val_y:
#
# File c:\Python310\lib\site-packages\sklearn\utils\validation.py:879, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     877         array = xp.astype(array, dtype, copy=False)
#     878     else:
# --> 879         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     880 except ComplexWarning as complex_warning:
#     881     raise ValueError(
#     882         "Complex data not supported\n{}\n".format(array)
#     883     ) from complex_warning
#
# File c:\Python310\lib\site-packages\sklearn\utils\_array_api.py:185, in _asarray_with_order(array, dtype, order, copy, xp)
#     182     xp, _ = get_namespace(array)
#     183 if xp.__name__ in {"numpy", "numpy.array_api"}:
#     184     # Use NumPy API to support order
# --> 185     array = numpy.asarray(array, order=order, dtype=dtype)
#     186     return xp.asarray(array, copy=copy)
#     187 else:
#
# File c:\Python310\lib\site-packages\pandas\core\generic.py:2070, in NDFrame.__array__(self, dtype)
#    2069 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2070     return np.asarray(self._values, dtype=dtype)
#
# TypeError: float() argument must be a string or a real number, not 'NAType'
